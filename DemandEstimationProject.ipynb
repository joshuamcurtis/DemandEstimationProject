# %% [markdown]
# Joshua Curtis

# %% [markdown]
# ### General instructions:
# This is a group project. The name of the group members should appear clearly at the top of the notebook. Give variables and functions a meaningful name (as much as possible). Comment your code in a way that explains what is done (especially inside functions).

# %% [markdown]
# ### 1 Preparation
# The data for this project is on my Github page. In the course repository there
# is a file named cardata2005 (both in json and csv formats) which includes
# information on prices, quantities and features of cars sold in the US to private
# people. There is also a file named census historical household data.xls which
# contains the number of households in the US in previous years. When you
# are done, before submitting the notebook, re-run the whole notebook.

# %% [markdown]
# 1. In the beginning of your notebook have a box in which you import all the packages that will be used in the notebook. Each such package import should be commented on explaining what use will be made of this package (or group of packages) in your notebook.

# %%
# Packages used

#to upload the data:
import requests, json 

#for plotting:
import matplotlib.pyplot as plt 

# Dataframes and math:
import numpy as np
import pandas as pd
import math

# K-means clustering
from sklearn.cluster import KMeans

# For linear regression
import statsmodels.formula.api as smf

# %% [markdown]
# 2. import the data from Github and store it in a dataframe. Report how many cars are in the dataframe and how many columns it has.

# %%
url = "https://raw.githubusercontent.com/ArieBeresteanu/Econ-1923/main/demand_estimation/cardata2005.json"
res = requests.get(url).json()
cars = pd.DataFrame(res)
cars.to_excel("RawDemandEstimationData.xlsx", sheet_name='RawData')

# %%
n_cars, n_cols = cars.shape

print(f"The data contains information on {n_cars} cars and it has [n_cols] columns.")
#cars.info()
# Out:
# The data contains information on 2199 cars and it has [n_cols] columns.

# %%
# Remove blank rows from bottom of df
cars = cars.drop(cars.index[217:])

# %%
typeFix = ['Quantity','Price','wheel_base','length','width','mpg_city','mpg_highway','hp', 'disp','weight']
# Convert typeFix items from Object to float in order to use nlargest() and solve some other problems down the line.
cars[typeFix] = cars[typeFix].astype(float)
#convert hybrid to type int
cars['hybrid'] = cars['hybrid'].astype(float)
#cars[typeFix] = pd.to_numeric(cars[typeFix],errors ='coerce')
#cars.info()

# %% [markdown]
# 3. create a new column in your dataframe which includes the name of the category in which each car is included.

# %%
cars['category'] = cars['segm1'].map(lambda x: math.floor((x)/10))

# using a dictionary

categoryDict = {
    '0': 'passenger cars',
    '2': 'minivans',
    '3': 'SUV',
    '4': 'light trucks'   
}
cars['categoryName'] = cars['category'].map(lambda x: categoryDict[str(x)])

carCat = pd.crosstab(index=cars['categoryName'], columns='count')

cars
# Create new variables:
# new features: footprint ect
# market shares: get # HHs
# Catagorical Variables (grouping)
# IV's (Based on features / ---- source)
# -- List of features
# -- feature averages per category
# -- dist2cat
# -- dist2cat/2
# Out:
#     car  year firm_id firm_name    division        model  hybrid segm1  \
# 0     0  2005       3     HONDA       Acura          MDX     0.0    39
# 1     0  2005       8       BMW         BMW           X3     0.0    39
# 2     0  2005       8       BMW         BMW           X5     0.0    39
# 3     0  2005      19        GM       Buick      Rainier     0.0    34
# 4     0  2005      19        GM       Buick   Rendezvous     0.0    38
# ..   ..   ...     ...       ...         ...          ...     ...   ...
# 212   1  2005       7     VOLKS  volkswagen       passat     0.0     3
# 213   1  2005       6     VOLVO       volvo          S40     0.0     3
# 214   1  2005       6     VOLVO       volvo          s60     0.0     3
# 215   1  2005       6     VOLVO       volvo  v70 c70 s70     0.0     4
# 216   1  2005       6     VOLVO       volvo      s80 v80     0.0     5
#
#      Quantity    Price  ...  width  weight  disp     hp  mpg_city  \
# 0     57948.0  36970.0  ...   77.0  4451.0   3.5  265.0      17.0
# 1     30769.0  30995.0  ...   73.0  4001.0   2.5  184.0      17.0
# 2     37598.0  42395.0  ...   73.7  4652.0   3.0  225.0      15.0
# 3     15271.0  35765.0  ...   75.4  4442.0   4.2  275.0      16.0
# 4     60589.0  27270.0  ...   73.6  4024.0   3.4  185.0      19.0
# ..        ...      ...  ...    ...     ...   ...    ...       ...
# 212   49233.0  24955.0  ...   68.7  3422.0   1.8  170.0      21.0
# 213   24241.0  23945.0  ...   69.7  3084.0   2.4  168.0      20.0
# 214   24695.0  27920.0  ...   71.0  3662.0   2.4  168.0      19.0
# 215   22823.0  29445.0  ...   71.0  3448.0   2.4  168.0      19.0
# 216   10181.0  36585.0  ...   72.1  3576.0   2.5  208.0      19.0
#
#      mpg_highway     __1 category    categoryName
# 0           23.0                3             SUV
# 1           24.0                3             SUV
# 2           21.0                3             SUV
# 3           21.0                3             SUV
# 4           26.0                3             SUV
# ..           ... ..  ...      ...             ...
# 212         30.0                0  passenger cars
# 213         27.0                0  passenger cars
# 214         26.0                0  passenger cars
# 215         26.0                0  passenger cars
# 216         26.0                0  passenger cars
#
# [217 rows x 22 columns]

# %% [markdown]
# 4. report descriptive statistics for the features of the cars in the data as well as prices and quantities. I leave it to you to decide how and what. General rule is that descriptive statistics, as the name suggests, are meant to describe the data in some way which is informative. Comment on your findings.

# %% [markdown]
# ### Number of car models in each category

# %%
# Count number of models by category name 
cars.groupby(['categoryName']).size()
# Out:
# categoryName
# SUV                71
# light trucks       14
# minivans           16
# passenger cars    116
# dtype: int64

# %% [markdown]
# ### Number of cars sold in each category

# %%
# Get the total quantity sold of each category 
cars.groupby(['categoryName'])['Quantity'].sum()
# Out:
# categoryName
# SUV               4419393.0
# light trucks      3094809.0
# minivans          1132949.0
# passenger cars    7378033.0
# Name: Quantity, dtype: float64

# %% [markdown]
# ### Mean of variables in each category

# %%
discChars = ['Quantity','Price','wheel_base','length','width','mpg_city','mpg_highway','hp', 'disp','weight']
print(cars.groupby(['categoryName'])[discChars].mean())
# Out:
#                      Quantity         Price  wheel_base      length  \
# categoryName
# SUV              62244.971831  32046.380282  111.636620  189.300000
# light trucks    221057.785714  20363.142857  122.257143  205.364286
# minivans         70809.312500  24172.812500  126.531250  201.681250
# passenger cars   63603.732759  28973.931034  106.210345  183.897414
#
#                     width   mpg_city  mpg_highway          hp      disp  \
# categoryName
# SUV             74.469014  17.126761    22.014085  229.126761  3.714085
# light trucks    73.792857  18.285714    23.428571  218.142857  3.835714
# minivans        76.537500  17.312500    23.000000  201.500000  3.706250
# passenger cars  71.014655  22.525862    29.206897  192.387931  2.830172
#
#                      weight
# categoryName
# SUV             4313.521127
# light trucks    4128.500000
# minivans        4337.000000
# passenger cars  3261.431034

# %% [markdown]
# ### Standard deviation of features in each category

# %%
cars.groupby(['categoryName'])[discChars].std()
# Out:
#                      Quantity         Price  wheel_base     length     width  \
# categoryName
# SUV              56580.169919  12208.051861    8.700579  14.640921  3.692099
# light trucks    268992.032165   7390.979782   11.365313  15.438743  4.783861
# minivans         68802.863987   2377.987222   24.071746  10.885171  2.604835
# passenger cars   74602.601515  15670.670565    6.399013  13.316426  3.433372
#
#                 mpg_city  mpg_highway         hp      disp      weight
# categoryName
# SUV             3.593365     4.148986  56.038999  1.128500  918.357087
# light trucks    3.770912     4.182643  68.067678  1.288772  849.263369
# minivans        1.922455     3.119829  25.250743  0.593822  410.646157
# passenger cars  6.780357     5.089661  63.624137  0.937176  512.998368

# %% [markdown]
# ### Min of features in each category

# %%
cars.groupby(['categoryName'])[discChars].min()
# Out:
#                 Quantity    Price  wheel_base  length  width  mpg_city  \
# categoryName
# SUV               1334.0  14195.0        93.4   150.2   66.5      12.0
# light trucks      5872.0  13980.0       109.4   187.5   66.2      12.0
# minivans          3436.0  18995.0       111.2   189.3   72.0      14.0
# passenger cars     666.0  10390.0        89.2   143.1   65.7      16.0
#
#                 mpg_highway     hp  disp  weight
# categoryName
# SUV                    14.0  108.0   1.5  2269.0
# light trucks           16.0  143.0   2.3  3010.0
# minivans               18.0  150.0   2.4  3772.0
# passenger cars         23.0   67.0   1.0  1850.0

# %% [markdown]
# ### Max of features in each category

# %%
cars.groupby(['categoryName'])[discChars].max()
# Out:
#                 Quantity    Price  wheel_base  length  width  mpg_city  \
# categoryName
# SUV             244150.0  78420.0       137.1   226.4   84.3      30.0
# light trucks    901463.0  43055.0       140.5   229.7   79.6      24.0
# minivans        180759.0  29695.0       211.0   224.1   79.4      20.0
# passenger cars  431703.0  90620.0       121.5   216.2   83.0      61.0
#
#                 mpg_highway     hp  disp  weight
# categoryName
# SUV                    34.0  345.0   6.0  6680.0
# light trucks           29.0  345.0   5.7  5648.0
# minivans               27.0  255.0   4.6  5258.0
# passenger cars         56.0  400.0   6.0  4399.0

# %% [markdown]
# ### Number of car models for each firm

# %%
# Count number of models by firm name 
cars.groupby(['firm_name']).size()
# Out:
# firm_name
# BMW          6
# CHRYSLER    16
# FORD        25
# GM          46
# HONDA       14
# HYUNDAI      7
# ISUZU        1
# JAGUAR       4
# KIA          6
# LAND         2
# MAZDA        6
# MERCEDEZ     8
# MINI         1
# MITSUBIS     6
# NISSAN      15
# PORSCHE      3
# SAAB         3
# SUBARU       4
# SUZUKI       4
# TOYOTA      25
# VOLKS       10
# VOLVO        5
# dtype: int64

# %% [markdown]
# ### Number of cars sold by each firm

# %%
# Get the total quantity sold of each firm 
cars.groupby(['firm_name'])['Quantity'].sum()
# Out:
# firm_name
# BMW          256249.0
# CHRYSLER    2019001.0
# FORD        2914332.0
# GM          4024172.0
# HONDA       1411886.0
# HYUNDAI      455012.0
# ISUZU          7585.0
# JAGUAR        30424.0
# KIA          246842.0
# LAND          21487.0
# MAZDA        238903.0
# MERCEDEZ     202955.0
# MINI          40820.0
# MITSUBIS     118638.0
# NISSAN      1051466.0
# PORSCHE       30449.0
# SAAB          36071.0
# SUBARU       181205.0
# SUZUKI        66396.0
# TOYOTA      2252323.0
# VOLKS        301052.0
# VOLVO        117916.0
# Name: Quantity, dtype: float64

# %% [markdown]
# ### Mean of features for each firm

# %%
cars.groupby(['firm_name'])[discChars].mean()
# Out:
#                 Quantity         Price  wheel_base      length      width  \
# firm_name
# BMW         42708.166667  41828.333333  109.666667  181.516667  72.150000
# CHRYSLER   126187.562500  23457.125000  112.562500  189.368750  73.968750
# FORD       116573.280000  27707.200000  115.404000  198.952000  74.332000
# GM          87482.000000  28484.021739  116.300000  196.195652  73.956522
# HONDA      100849.000000  25946.071429  105.250000  181.914286  71.192857
# HYUNDAI     65001.714286  17594.714286  102.800000  177.728571  69.985714
# ISUZU        7585.000000  29254.000000  129.000000  207.600000  76.100000
# JAGUAR       7606.000000  51970.000000  110.650000  191.325000  81.150000
# KIA         41140.333333  17730.833333  105.916667  183.166667  71.066667
# LAND        10743.500000  36245.000000  107.350000  182.500000  78.450000
# MAZDA       39817.166667  19341.333333  104.150000  178.633333  69.783333
# MERCEDEZ    25369.375000  56465.000000  108.425000  182.650000  70.812500
# MINI        40820.000000  16999.000000   97.100000  143.100000  66.500000
# MITSUBIS    19773.000000  22396.500000  105.466667  184.566667  70.900000
# NISSAN      70097.733333  28709.333333  115.246667  194.040000  73.646667
# PORSCHE     10149.666667  52185.000000  100.066667  178.100000  72.666667
# SAAB        12023.666667  29408.333333  103.700000  182.100000  69.200000
# SUBARU      45301.250000  21795.000000  102.050000  182.125000  68.750000
# SUZUKI      16599.000000  16244.000000  100.975000  175.175000  69.300000
# TOYOTA      90092.920000  29914.600000  108.048000  184.360000  71.568000
# VOLKS       30105.200000  32846.500000  105.650000  179.570000  72.840000
# VOLVO       23583.200000  30684.000000  108.380000  184.040000  71.640000
#
#             mpg_city  mpg_highway          hp      disp       weight
# firm_name
# BMW        18.333333    26.000000  214.333333  2.900000  3766.166667
# CHRYSLER   19.500000    24.500000  192.562500  3.087500  3809.500000
# FORD       18.080000    23.640000  217.720000  3.884000  4143.600000
# GM         18.521739    24.717391  220.652174  3.895652  4015.369565
# HONDA      27.214286    32.142857  193.500000  2.557143  3333.428571
# HYUNDAI    23.000000    29.285714  146.000000  2.314286  3068.000000
# ISUZU      15.000000    19.000000  275.000000  4.200000  4790.000000
# JAGUAR     18.000000    26.000000  253.750000  3.475000  3715.000000
# KIA        20.000000    27.000000  161.166667  2.750000  3553.333333
# LAND       15.500000    19.500000  237.000000  3.450000  4533.000000
# MAZDA      20.833333    26.500000  157.666667  2.283333  3198.666667
# MERCEDEZ   18.000000    24.250000  246.750000  3.712500  4052.500000
# MINI       28.000000    37.000000  115.000000  1.600000  2700.000000
# MITSUBIS   21.166667    27.000000  170.333333  2.800000  3468.833333
# NISSAN     18.400000    24.333333  256.800000  3.806667  3850.400000
# PORSCHE    18.666667    26.000000  267.333333  3.166667  3626.333333
# SAAB       20.666667    28.666667  186.666667  2.266667  3275.000000
# SUBARU     22.000000    26.500000  177.000000  2.500000  3186.750000
# SUZUKI     21.500000    27.750000  150.250000  2.325000  2962.500000
# TOYOTA     22.640000    27.840000  199.840000  3.080000  3585.240000
# VOLKS      20.300000    26.900000  194.500000  2.470000  3571.800000
# VOLVO      19.000000    25.800000  184.000000  2.440000  3644.000000

# %% [markdown]
# ### Min of features for each firm

# %%
cars.groupby(['firm_name'])[discChars].min()
# Out:
#            Quantity    Price  wheel_base  length  width  mpg_city  \
# firm_name
# BMW         10045.0  29995.0        98.2   161.1   68.5      15.0
# CHRYSLER    14665.0  14160.0        93.4   150.2   67.1      12.0
# FORD         8166.0  14235.0       103.0   174.3   66.2      12.0
# GM           3436.0  11995.0       100.5   171.9   67.2      12.0
# HONDA         666.0  14375.0        94.5   155.1   66.7      17.0
# HYUNDAI     17645.0  10544.0        96.1   166.7   65.7      18.0
# ISUZU        7585.0  29254.0       129.0   207.6   76.1      15.0
# JAGUAR       2282.0  30995.0       102.0   183.9   78.8      18.0
# KIA         18668.0  10390.0        94.9   166.9   65.9      16.0
# LAND         2141.0  27495.0       101.1   174.1   75.4      14.0
# MAZDA        5872.0  14225.0        89.2   155.3   66.0      18.0
# MERCEDEZ     1334.0  26570.0        95.7   160.7   68.0      13.0
# MINI        40820.0  16999.0        97.1   143.1   66.5      28.0
# MITSUBIS     2778.0  14574.0       100.8   176.8   66.8      15.0
# NISSAN       1129.0  13060.0        99.8   169.4   67.3      13.0
# PORSCHE      7879.0  41915.0        92.6   170.4   70.9      16.0
# SAAB         5940.0  23685.0        99.4   173.8   68.1      20.0
# SUBARU       6239.0  18670.0        99.4   173.8   68.1      19.0
# SUZUKI       7967.0  13994.0        97.6   164.6   67.7      19.0
# TOYOTA       3113.0  12995.0        93.3   154.1   66.5      13.0
# VOLKS        2429.0  16405.0        95.4   159.1   67.9      15.0
# VOLVO       10181.0  23945.0       103.9   175.9   69.7      18.0
#
#            mpg_highway     hp  disp  weight
# firm_name
# BMW               21.0  184.0   2.5  2932.0
# CHRYSLER          16.0  132.0   2.0  2581.0
# FORD              15.0  136.0   2.0  2697.0
# GM                15.0  130.0   1.8  2692.0
# HONDA             22.0   67.0   1.0  1850.0
# HYUNDAI           25.0  104.0   1.6  2280.0
# ISUZU             19.0  275.0   4.2  4790.0
# JAGUAR            26.0  192.0   2.5  3498.0
# KIA               19.0  104.0   1.6  2403.0
# LAND              18.0  174.0   2.5  3640.0
# MAZDA             24.0  142.0   1.8  2447.0
# MERCEDEZ          14.0  189.0   1.8  3231.0
# MINI              37.0  115.0   1.6  2700.0
# MITSUBIS          19.0  120.0   2.0  2656.0
# NISSAN            19.0  126.0   1.8  2269.0
# PORSCHE           20.0  240.0   2.7  2855.0
# SAAB              28.0  165.0   2.0  3070.0
# SUBARU            25.0  165.0   2.5  2972.0
# SUZUKI            22.0  126.0   2.0  2661.0
# TOYOTA            17.0   76.0   1.5  2340.0
# VOLKS             20.0  115.0   1.8  2743.0
# VOLVO             24.0  168.0   2.4  3084.0

# %% [markdown]
# ### Max of features for each firm

# %%
cars.groupby(['firm_name'])[discChars].max()
# Out:
#            Quantity    Price  wheel_base  length  width  mpg_city  \
# firm_name
# BMW        106950.0  70595.0       117.7   198.0   74.9      21.0
# CHRYSLER   400543.0  34620.0       140.5   229.7   84.3      29.0
# FORD       901463.0  50435.0       138.0   226.6   79.9      26.0
# GM         705980.0  53895.0       211.0   224.1   81.2      30.0
# HONDA      352467.0  49470.0       118.1   201.2   77.3      61.0
# HYUNDAI    130365.0  24994.0       108.3   191.9   72.7      29.0
# ISUZU        7585.0  29254.0       129.0   207.6   76.1      15.0
# JAGUAR      10941.0  70495.0       119.4   200.4   83.0      18.0
# KIA         56088.0  25790.0       114.6   196.0   74.6      25.0
# LAND        19346.0  44995.0       113.6   190.9   81.5      17.0
# MAZDA       97388.0  23485.0       111.8   189.5   72.1      24.0
# MERCEDEZ    60658.0  90620.0       121.5   203.1   73.1      24.0
# MINI        40820.0  16999.0        97.1   143.1   66.5      28.0
# MITSUBIS    33976.0  35799.0       109.7   190.6   74.8      27.0
# NISSAN     255371.0  56490.0       139.8   224.2   78.8      28.0
# PORSCHE     13607.0  70095.0       112.4   188.3   75.9      20.0
# SAAB        24108.0  36970.0       106.4   190.0   70.5      21.0
# SUBARU      87788.0  24770.0       105.1   193.3   70.1      23.0
# SUZUKI      41394.0  18994.0       106.3   187.6   71.5      25.0
# TOYOTA     431703.0  65400.0       128.3   218.3   78.9      60.0
# VOLKS      104063.0  70620.0       121.1   204.0   79.2      25.0
# VOLVO       35976.0  36585.0       112.6   189.8   74.4      20.0
#
#            mpg_highway     hp  disp  weight
# firm_name
# BMW               29.0  325.0   4.4  4652.0
# CHRYSLER          32.0  345.0   5.7  5453.0
# FORD              32.0  302.0   5.4  6680.0
# GM                35.0  400.0   6.0  6400.0
# HONDA             56.0  300.0   3.5  4451.0
# HYUNDAI           35.0  194.0   3.5  3651.0
# ISUZU             19.0  275.0   4.2  4790.0
# JAGUAR            26.0  294.0   4.2  3806.0
# KIA               34.0  200.0   3.5  4802.0
# LAND              21.0  300.0   4.4  5426.0
# MAZDA             29.0  200.0   3.0  3994.0
# MERCEDEZ          32.0  302.0   5.0  5545.0
# MINI              37.0  115.0   1.6  2700.0
# MITSUBIS          31.0  225.0   3.8  4787.0
# NISSAN            34.0  340.0   5.6  5360.0
# PORSCHE           29.0  315.0   3.6  4949.0
# SAAB              30.0  220.0   2.5  3580.0
# SUBARU            30.0  210.0   2.5  3485.0
# SUZUKI            31.0  165.0   2.5  3380.0
# TOYOTA            51.0  300.0   4.7  5900.0
# VOLKS             31.0  335.0   4.2  5086.0
# VOLVO             27.0  208.0   2.5  4450.0

# %% [markdown]
# ### Standard deviations of features for each firm

# %%
cars.groupby(['firm_name'])[discChars].std()
# Out:
#                 Quantity         Price  wheel_base     length     width  \
# firm_name
# BMW         34828.715161  15046.284148    6.631038  12.724373  2.388095
# CHRYSLER    90435.593818   5159.983358   12.527669  20.432383  4.973358
# FORD       177447.573102   8919.377440    9.722932  14.169160  3.731255
# GM         115303.873980  10732.886462   16.555241  12.858373  4.077780
# HONDA      107674.381737   9362.187692    5.304244  12.008321  3.611193
# HYUNDAI     44200.118042   4836.993237    4.045986   8.986418  2.505613
# ISUZU                NaN           NaN         NaN        NaN       NaN
# JAGUAR       3724.740975  17549.050307    7.784814   7.102758  1.755942
# KIA         14316.985558   5546.855340    6.716969  11.071525  3.317027
# LAND        12165.772170  12374.368671    8.838835  11.879394  4.313351
# MAZDA       37066.224105   3651.368876    8.246393  12.852030  2.249815
# MERCEDEZ    21081.765634  22390.506279    7.859071  11.914577  1.777990
# MINI                 NaN           NaN         NaN        NaN       NaN
# MITSUBIS    11154.280577   7527.035107    3.737735   6.428271  3.148333
# NISSAN      60059.889184  11542.990741   10.173766  14.147579  3.626464
# PORSCHE      3042.799588  15566.158807   10.759802   9.208149  2.804164
# SAAB        10465.421938   6830.622836    3.764306   8.107404  1.212436
# SUBARU      34326.527685   2491.819951    3.077337   9.287043  0.914695
# SUZUKI      16532.265604   2629.955640    4.209810   9.752393  1.825742
# TOYOTA      92624.896527  16226.036942    7.347625  14.701672  3.503061
# VOLKS       31350.433797  16424.422880    8.016130  14.929319  4.194494
# VOLVO        9157.608323   5311.450367    3.244534   5.908722  1.761533
#
#             mpg_city  mpg_highway         hp      disp       weight
# firm_name
# BMW         2.160247     3.033150  56.641563  0.761577   682.478840
# CHRYSLER    4.082483     4.016632  55.953515  0.913510   744.444312
# FORD        3.639139     4.405300  51.383785  1.068363   938.794617
# GM          3.981843     5.230947  61.550058  1.068739   875.556746
# HONDA      12.861263     9.493780  74.323358  0.846453   787.237596
# HYUNDAI     4.000000     3.545621  28.495614  0.628301   489.629111
# ISUZU            NaN          NaN        NaN       NaN          NaN
# JAGUAR      0.000000     0.000000  49.681485  0.861684   145.269864
# KIA         4.147288     5.932959  39.861845  0.859651   918.029774
# LAND        2.121320     2.121320  89.095454  1.343503  1262.892711
# MAZDA       3.125167     2.428992  21.786846  0.407022   598.096871
# MERCEDEZ    3.464102     5.824824  43.100381  1.061586   800.167125
# MINI             NaN          NaN        NaN       NaN          NaN
# MITSUBIS    4.400758     4.939636  41.311822  0.789937   766.412269
# NISSAN      4.239272     4.353433  60.969782  1.140468   911.786300
# PORSCHE     2.309401     5.196152  41.428654  0.450925  1150.732520
# SAAB        0.577350     1.154701  29.297326  0.251661   269.304660
# SUBARU      2.000000     2.380476  22.045408  0.000000   219.550108
# SUZUKI      2.645751     4.031129  16.839933  0.236291   343.880309
# TOYOTA      9.530128     7.803204  64.305054  1.116169   941.328949
# VOLKS       3.653005     3.984693  73.728104  0.824688   794.521911
# VOLVO       0.707107     1.095445  21.908902  0.054772   501.647286

# %% [markdown]
# ### Count of models for each division

# %%
# Count number of models by firm name 
cars.groupby(['division']).size()
# Out:
# division
# Acura          1
# BMW            2
# Buick          2
# Cadillac       3
# Chevrolet     12
#               ..
# subaru         1
# suzuki         1
# toyota         1
# volkswagen     5
# volvo          4
# Length: 61, dtype: int64

# %% [markdown]
# ### Mean of features for each division

# %%
cars.groupby(['division'])[discChars].mean()
# Out:
#                  Quantity         Price  wheel_base      length      width  \
# division
# Acura        57948.000000  36970.000000  106.300000  188.700000  77.000000
# BMW          34183.500000  36695.000000  110.550000  181.700000  73.350000
# Buick        37930.000000  31517.500000  112.600000  189.950000  74.500000
# Cadillac     24714.333333  48881.666667  120.666667  204.966667  77.000000
# Chevrolet   139867.083333  27732.083333  125.458333  199.800000  75.416667
# ...                   ...           ...         ...         ...        ...
# subaru       53541.000000  21870.000000   99.400000  175.200000  68.300000
# suzuki        7967.000000  13994.000000   97.600000  171.300000  67.700000
# toyota      107897.000000  21415.000000  106.300000  175.000000  67.900000
# volkswagen   44675.000000  22903.000000  103.060000  174.140000  69.820000
# volvo        20485.000000  29473.750000  107.325000  182.825000  70.950000
#
#              mpg_city  mpg_highway          hp      disp       weight
# division
# Acura       17.000000    23.000000  265.000000  3.500000  4451.000000
# BMW         16.000000    22.500000  204.500000  2.750000  4326.500000
# Buick       17.500000    23.500000  230.000000  3.800000  4233.000000
# Cadillac    14.333333    19.333333  298.333333  4.966667  5160.666667
# Chevrolet   16.333333    21.583333  229.583333  4.308333  4325.250000
# ...               ...          ...         ...       ...          ...
# subaru      23.000000    30.000000  165.000000  2.500000  3090.000000
# suzuki      25.000000    31.000000  155.000000  2.300000  2661.000000
# toyota      60.000000    51.000000   76.000000  1.500000  2890.000000
# volkswagen  21.800000    28.200000  151.000000  2.200000  3391.200000
# volvo       19.250000    26.250000  178.000000  2.425000  3442.500000
#
# [61 rows x 10 columns]

# %% [markdown]
# 5. How many hybrid cars are included in the data set? Which are these cars and to which category they belong? Comment on your findings.

# %%
print(cars.groupby(['hybrid']).size())
print(' ')
print(cars.groupby(['categoryName', 'hybrid']).size())
# Out:
# hybrid
# 0.0    213
# 1.0      4
# dtype: int64
#
# categoryName    hybrid
# SUV             0.0        71
# light trucks    0.0        14
# minivans        0.0        16
# passenger cars  0.0       112
#                 1.0         4
# dtype: int64

# %% [markdown]
# There are only 4 hybrid cars from the 2005 data sets. All of the hybrid cars belong to the passenger cars category.

# %% [markdown]
# 6. What were the top 3 and bottom 3 selling car models in the US in 2005?

# %%
#Get three top 3 selling cars
print(cars[['firm_name','division','model','Quantity']].nlargest(3,'Quantity'))
# Out:
#     firm_name   division          model  Quantity
# 33       FORD       Ford       F series  901463.0
# 14         GM  Chevrolet  Silverado C/K  705980.0
# 204    TOYOTA     TOYOTA          camry  431703.0

# %%
#Get bottom top 3 selling cars
print(cars[['firm_name','division','model','Quantity']].nsmallest(3,'Quantity'))
# Out:
#     firm_name  division    model  Quantity
# 140     HONDA     honda  insight     666.0
# 147    NISSAN  infiniti  q45 m45    1129.0
# 71   MERCEDEZ  MERCEDEZ  G class    1334.0

# %% [markdown]
# 7. Declare a variable that contains the number of households in the US in 2005 (taken from the excel file on my Github page).

# %%
Households = 113343000

# %% [markdown]
# 8. Define variables like footprint and combined miles per gallon (and any other variables that you might need).

# %%
# Combined mpg
cars['mpg_combined'] = cars['mpg_city']*0.55+cars['mpg_highway']*0.45

# foot print in 100s of square inches 
cars['footprint'] = cars['width'] * cars['length'] /1000  #rescaling

#create dummy cariables for categories
# do not create dummy variable for light trucks to avoid multi-colinearity
cars['SUV'] = np.where(cars['categoryName'] == 'SUV', 1, 0)
cars['passenger_cars'] = np.where(cars['categoryName'] == 'passenger cars', 1, 0)
cars['minivans'] = np.where(cars['categoryName'] == 'minivans', 1, 0)
cars
# Out:
#     car  year firm_id firm_name    division        model  hybrid segm1  \
# 0     0  2005       3     HONDA       Acura          MDX     0.0    39
# 1     0  2005       8       BMW         BMW           X3     0.0    39
# 2     0  2005       8       BMW         BMW           X5     0.0    39
# 3     0  2005      19        GM       Buick      Rainier     0.0    34
# 4     0  2005      19        GM       Buick   Rendezvous     0.0    38
# ..   ..   ...     ...       ...         ...          ...     ...   ...
# 212   1  2005       7     VOLKS  volkswagen       passat     0.0     3
# 213   1  2005       6     VOLVO       volvo          S40     0.0     3
# 214   1  2005       6     VOLVO       volvo          s60     0.0     3
# 215   1  2005       6     VOLVO       volvo  v70 c70 s70     0.0     4
# 216   1  2005       6     VOLVO       volvo      s80 v80     0.0     5
#
#      Quantity    Price  ...  mpg_highway     __1  category    categoryName  \
# 0     57948.0  36970.0  ...         23.0                 3             SUV
# 1     30769.0  30995.0  ...         24.0                 3             SUV
# 2     37598.0  42395.0  ...         21.0                 3             SUV
# 3     15271.0  35765.0  ...         21.0                 3             SUV
# 4     60589.0  27270.0  ...         26.0                 3             SUV
# ..        ...      ...  ...          ... ..  ...       ...             ...
# 212   49233.0  24955.0  ...         30.0                 0  passenger cars
# 213   24241.0  23945.0  ...         27.0                 0  passenger cars
# 214   24695.0  27920.0  ...         26.0                 0  passenger cars
# 215   22823.0  29445.0  ...         26.0                 0  passenger cars
# 216   10181.0  36585.0  ...         26.0                 0  passenger cars
#
#      mpg_combined  footprint  SUV passenger_cars minivans
# 0           19.70   14.52990    1              0        0
# 1           20.15   13.11810    1              0        0
# 2           17.70   13.53869    1              0        0
# 3           18.25   14.58236    1              0        0
# 4           22.15   13.72640    1              0        0
# ..            ...        ...  ...            ...      ...
# 212         25.05   12.72324    0              1        0
# 213         23.15   12.26023    0              1        0
# 214         22.15   12.79420    0              1        0
# 215         22.15   13.16340    0              1        0
# 216         22.15   13.68458    0              1        0
#
# [217 rows x 27 columns]

# %% [markdown]
# # 2 First Stage Regression
# 1. Generate instrumental variables which are based on the distance of a product from the set of products it competes with. Consider generating instrumental variables which are based on features that you intend to use in the second stage as well as on features that you will not use in the second stage.

# %%
# Run the 1st stage regression and save the predicted values 
characteristics = ['mpg_combined','footprint', 'hp', 'disp', 'weight', 'hybrid']

featuresAvg = cars.groupby(['categoryName'])[characteristics].mean()

cars['categoryCount'] = cars['categoryName'].map(lambda x: carCat.loc[x,'count'])

def dist2Cat(characteristics):
    #characteristics is a list of strings. Each string in the list is a name of a characteristic
    for ch in characteristics:
        # 1. expand
        cars[ch+'Avg'] = cars['categoryName'].map(lambda x: featuresAvg[ch][x])
        # 2. difference
        cars[ch+'Dist'] = cars[ch]-cars[ch+'Avg']
        # 3. square
        cars[ch+'Dist'] = cars[ch+'Dist'].map(lambda x: x*x)

dist2Cat(characteristics)
cars
# Out:
#     car  year firm_id firm_name    division        model  hybrid segm1  \
# 0     0  2005       3     HONDA       Acura          MDX     0.0    39
# 1     0  2005       8       BMW         BMW           X3     0.0    39
# 2     0  2005       8       BMW         BMW           X5     0.0    39
# 3     0  2005      19        GM       Buick      Rainier     0.0    34
# 4     0  2005      19        GM       Buick   Rendezvous     0.0    38
# ..   ..   ...     ...       ...         ...          ...     ...   ...
# 212   1  2005       7     VOLKS  volkswagen       passat     0.0     3
# 213   1  2005       6     VOLVO       volvo          S40     0.0     3
# 214   1  2005       6     VOLVO       volvo          s60     0.0     3
# 215   1  2005       6     VOLVO       volvo  v70 c70 s70     0.0     4
# 216   1  2005       6     VOLVO       volvo      s80 v80     0.0     5
#
#      Quantity    Price  ...  footprintAvg  footprintDist       hpAvg  \
# 0     57948.0  36970.0  ...     14.134972       0.155968  229.126761
# 1     30769.0  30995.0  ...     14.134972       1.034029  229.126761
# 2     37598.0  42395.0  ...     14.134972       0.355552  229.126761
# 3     15271.0  35765.0  ...     14.134972       0.200156  229.126761
# 4     60589.0  27270.0  ...     14.134972       0.166931  229.126761
# ..        ...      ...  ...           ...            ...         ...
# 212   49233.0  24955.0  ...     13.089287       0.133990  192.387931
# 213   24241.0  23945.0  ...     13.089287       0.687335  192.387931
# 214   24695.0  27920.0  ...     13.089287       0.087076  192.387931
# 215   22823.0  29445.0  ...     13.089287       0.005493  192.387931
# 216   10181.0  36585.0  ...     13.089287       0.354374  192.387931
#
#           hpDist   dispAvg  dispDist    weightAvg     weightDist hybridAvg  \
# 0    1286.889308  3.714085  0.045832  4313.521127   18900.440587  0.000000
# 1    2036.424519  3.714085  1.474001  4313.521127   97669.454672  0.000000
# 2      17.030153  3.714085  0.509917  4313.521127  114567.947629  0.000000
# 3    2104.354096  3.714085  0.236114  4313.521127   16506.820869  0.000000
# 4    1947.170998  3.714085  0.098649  4313.521127   83822.482841  0.000000
# ..           ...       ...       ...          ...            ...       ...
# 212   501.219456  2.830172  1.061255  3261.431034   25782.392687  0.034483
# 213   594.771180  2.830172  0.185048  3261.431034   31481.771998  0.034483
# 214   594.771180  2.830172  0.185048  3261.431034  160455.496136  0.034483
# 215   594.771180  2.830172  0.185048  3261.431034   34807.978894  0.034483
# 216   243.736697  2.830172  0.109014  3261.431034   98953.634067  0.034483
#
#     hybridDist
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     0.000000
# 4     0.000000
# ..         ...
# 212   0.001189
# 213   0.001189
# 214   0.001189
# 215   0.001189
# 216   0.001189
#
# [217 rows x 40 columns]

# %%
def dist2CatV2(characteristics):
    #characteristics is a list of strings. Each string in the list is a name of a characteristic
    for ch in characteristics:
        # 1. expand
        #cars[ch+'Avg'] = cars['categoryName'].map(lambda x: featuresAvg[ch][x])
        cars[ch+'Avg2'] = (cars[ch+'Avg']*cars['categoryCount'] - cars[ch])/(cars['categoryCount']-1)
        # 2. difference
        cars[ch+'Dist2'] = cars[ch]-cars[ch+'Avg2']
        # 3. square
        cars[ch+'Dist2'] = cars[ch+'Dist2'].map(lambda x: x*x)

dist2CatV2(characteristics)
cars
# Out:
#     car  year firm_id firm_name    division        model  hybrid segm1  \
# 0     0  2005       3     HONDA       Acura          MDX     0.0    39
# 1     0  2005       8       BMW         BMW           X3     0.0    39
# 2     0  2005       8       BMW         BMW           X5     0.0    39
# 3     0  2005      19        GM       Buick      Rainier     0.0    34
# 4     0  2005      19        GM       Buick   Rendezvous     0.0    38
# ..   ..   ...     ...       ...         ...          ...     ...   ...
# 212   1  2005       7     VOLKS  volkswagen       passat     0.0     3
# 213   1  2005       6     VOLVO       volvo          S40     0.0     3
# 214   1  2005       6     VOLVO       volvo          s60     0.0     3
# 215   1  2005       6     VOLVO       volvo  v70 c70 s70     0.0     4
# 216   1  2005       6     VOLVO       volvo      s80 v80     0.0     5
#
#      Quantity    Price  ...  footprintAvg2  footprintDist2      hpAvg2  \
# 0     57948.0  36970.0  ...      14.129330        0.160456  228.614286
# 1     30769.0  30995.0  ...      14.149499        1.063783  229.771429
# 2     37598.0  42395.0  ...      14.143490        0.365783  229.185714
# 3     15271.0  35765.0  ...      14.128581        0.205916  228.471429
# 4     60589.0  27270.0  ...      14.140809        0.171735  229.757143
# ..        ...      ...  ...            ...             ...         ...
# 212   49233.0  24955.0  ...      13.092470        0.136331  192.582609
# 213   24241.0  23945.0  ...      13.096496        0.699341  192.600000
# 214   24695.0  27920.0  ...      13.091853        0.088597  192.600000
# 215   22823.0  29445.0  ...      13.088642        0.005589  192.600000
# 216   10181.0  36585.0  ...      13.084110        0.360564  192.252174
#
#          hpDist2  dispAvg2  dispDist2   weightAvg2    weightDist2 hybridAvg2  \
# 0    1323.920204  3.717143   0.047151  4311.557143   19444.310408   0.000000
# 1    2095.023673  3.731429   1.516416  4317.985714  100479.943061   0.000000
# 2      17.520204  3.724286   0.524590  4308.685714  117864.698776   0.000000
# 3    2164.907959  3.707143   0.242908  4311.685714   16981.813061   0.000000
# 4    2003.201837  3.718571   0.101488  4317.657143   86234.517551   0.000000
# ..           ...       ...        ...          ...            ...        ...
# 212   509.974216  2.839130   1.079792  3260.034783   26232.731645   0.034783
# 213   605.160000  2.833913   0.188281  3262.973913   32031.661550   0.034783
# 214   605.160000  2.833913   0.188281  3257.947826  163258.159244   0.034783
# 215   605.160000  2.833913   0.188281  3259.808696   35415.967032   0.034783
# 216   247.994026  2.833043   0.110918  3258.695652  100682.049149   0.034783
#
#     hybridDist2
# 0       0.00000
# 1       0.00000
# 2       0.00000
# 3       0.00000
# 4       0.00000
# ..          ...
# 212     0.00121
# 213     0.00121
# 214     0.00121
# 215     0.00121
# 216     0.00121
#
# [217 rows x 52 columns]

# %% [markdown]
# 2. estimate the first stage regression and save the predicted values.

# %%
firstStage = smf.ols(formula='Price ~ SUV + minivans + passenger_cars + hybrid + disp + mpg_combined + footprint + dispDist2 + mpg_combinedDist2 + footprintDist2 + weightDist2 + hpDist2 + hybridDist2' ,data=cars).fit(cov_type='HC1')

print(firstStage.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.574
# Model:                            OLS   Adj. R-squared:                  0.549
# Method:                 Least Squares   F-statistic:                     23.84
# Date:                Sun, 24 Apr 2022   Prob (F-statistic):           1.11e-32
# Time:                        17:12:41   Log-Likelihood:                -2284.4
# No. Observations:                 217   AIC:                             4595.
# Df Residuals:                     204   BIC:                             4639.
# Df Model:                          12
# Covariance Type:                  HC1
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          4.052e+04   1.55e+04      2.623      0.009    1.02e+04    7.08e+04
# SUV                1.002e+04   3000.510      3.340      0.001    4140.670    1.59e+04
# minivans           5724.9209   3126.921      1.831      0.067    -403.731    1.19e+04
# passenger_cars     1.918e+04   3083.690      6.221      0.000    1.31e+04    2.52e+04
# hybrid             3608.3003   1227.114      2.940      0.003    1203.201    6013.399
# disp               4343.9128   1431.578      3.034      0.002    1538.072    7149.754
# mpg_combined      -1616.9816    307.684     -5.255      0.000   -2220.030   -1013.933
# footprint          -388.5585    904.680     -0.429      0.668   -2161.698    1384.581
# dispDist2          -693.8641   1747.376     -0.397      0.691   -4118.658    2730.929
# mpg_combinedDist2    37.0513      9.285      3.990      0.000      18.852      55.250
# footprintDist2     -644.6012    373.046     -1.728      0.084   -1375.759      86.556
# weightDist2           0.0021      0.001      1.476      0.140      -0.001       0.005
# hpDist2               0.7906      0.375      2.109      0.035       0.056       1.525
# hybridDist2        3441.3416   1162.341      2.961      0.003    1163.194    5719.489
# ==============================================================================
# Omnibus:                       37.142   Durbin-Watson:                   1.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.128
# Skew:                           0.847   Prob(JB):                     1.32e-16
# Kurtosis:                       5.285   Cond. No.                     2.32e+22
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is 3.34e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# C:\Users\Joshua\anaconda3\lib\site-packages\statsmodels\base\model.py:1832: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 13, but rank is 12
#   warnings.warn('covariance of constraints does not have full '

# %%
cars['Price_hat'] = firstStage.predict()

# %% [markdown]
# 3. What is the R2 parameter of the first stage regression? Is it high enough to believe that the instrumental variables you included are relevant to predicting the price?

# %% [markdown]
# R^2 = 0.574
#
# The following insturmental variables are significant at the **99% level**:
# - mpg_combinedDist2
# - hybridDist2
#
# The following insturmental variable are significant at the **95% level**:
# - hpDist2
#
# The following insturmental variable are significant at the **90% level**:
# - footprintDist2

# %% [markdown]
# ### 3 Second Stage regression
# 1. Create a correlation matrix for the features of the cars that you contemplate using in the second stage regression. If you see very high correlation coefficients (e.g. above 0.75 in absolute value). Comment on

# %%
cors = ['SUV', 'minivans', 'passenger_cars', 'hybrid', 'mpg_combined','footprint', 'hp', 'disp', 'weight', 'hybrid']

# %%
cars[cors].corr()
# Out:
#                      SUV  minivans  passenger_cars    hybrid  mpg_combined  \
# SUV             1.000000 -0.196750       -0.747345 -0.095564     -0.414570
# minivans       -0.196750  1.000000       -0.302364 -0.038664     -0.141116
# passenger_cars -0.747345 -0.302364        1.000000  0.127871      0.512306
# hybrid         -0.095564 -0.038664        0.127871  1.000000      0.599364
# mpg_combined   -0.414570 -0.141116        0.512306  0.599364      1.000000
# footprint       0.159864  0.280070       -0.406719 -0.149357     -0.628210
# hp              0.254423 -0.024105       -0.250722 -0.192065     -0.684828
# disp            0.295881  0.117693       -0.409201 -0.193571     -0.736297
# weight          0.466577  0.196510       -0.600406 -0.169033     -0.773875
# hybrid         -0.095564 -0.038664        0.127871  1.000000      0.599364
#
#                 footprint        hp      disp    weight    hybrid
# SUV              0.159864  0.254423  0.295881  0.466577 -0.095564
# minivans         0.280070 -0.024105  0.117693  0.196510 -0.038664
# passenger_cars  -0.406719 -0.250722 -0.409201 -0.600406  0.127871
# hybrid          -0.149357 -0.192065 -0.193571 -0.169033  1.000000
# mpg_combined    -0.628210 -0.684828 -0.736297 -0.773875  0.599364
# footprint        1.000000  0.632522  0.780299  0.806336 -0.149357
# hp               0.632522  1.000000  0.855611  0.716891 -0.192065
# disp             0.780299  0.855611  1.000000  0.837191 -0.193571
# weight           0.806336  0.716891  0.837191  1.000000 -0.169033
# hybrid          -0.149357 -0.192065 -0.193571 -0.169033  1.000000

# %% [markdown]
# ### SUV & passenger_cars
# - The correlation coefficient between SUV & passenger cars is high and negative because they are the two largest categories of cars, and obviously are mutually exclusive.
#
# ### mpg_combined and disp
# - mpg_combined has high negative correlations with both disp and weight. I'm not an engineer, but I believe a larger engine (higher disp) requires more gasoline; so higher disp would lead to lower mpg on average.
#
# ### mpg_combined and weight
# - Cars that weigh more should require more gasoline to drive a mile than cars that weigh less, holding all else equal.
#
# ### foot and disp / footprint & weight
# - footprint has a high positive correlation coefficient with both disp and weight. This makes sense since one would expect a car with a larger footprint to weigh more and have a larger engine.
#
# ### hp and disp
# - hp has a high positive correlation coefficient with disp. This makes sense since cars with more horse power will need a larger engine holding all else equal.
#
# ### disp and weight
# - disp has a high  positive correlation coefficient with weight. This makes sense since a heavier car will  need a larger engine (more displacement) to move at the same speed as a smaller car.

# %% [markdown]
# 2. Using the predicted value for price from the first stage regression, estimate the second stage regression. Include the dummy variable for the features, the dummy variables and the price. (Here it is important to use robust standard errors.)

# %%
# Run second stage regression and look at the coefficients

# From 96 data
# first stage: run regression on price
# X's: hp, mpgcombined, footprint, C('category')
# IV's: hpdist2, mpgcombined2, footprintdist2


# 2nd Stage also run regression on price, x's p-hat 
# Yj = (logshare ; -logshare0) / (hp, mpg_combined, footprint)
# j = toyota camry: alpha-hat = -8.135*10^-5, Pj = 16,758 ; Share = 0.331%, elasticity price = -alpha-hat * Pj = 0.455
# j = BMW: alpha-hat: -2.8713, Pj = 35300; Share = 0.0229% ; elasticity price = -alpha-hat * Pj = 0.0657%

# %%
cars['log_disp'] = cars['disp'].map(lambda x: math.log(x))
cars['log_mpg_combined'] = cars['mpg_combined'].map(lambda x: math.log(x))
cars['log_footprint'] = cars['footprint'].map(lambda x: math.log(x))
cars['LnMarkethare'] = (cars['Quantity']/Households).map(lambda x: math.log(x))
cars['logPrice'] = cars['Price'].map(lambda x: math.log(x))
cars['logPriceHat'] = cars['Price_hat'].map(lambda x: math.log(x))

# %%
outGood = Households - cars['Quantity'].sum()
shareOutGood = outGood/Households
#print(shareOutGood)
LnShareOutGood = math.log(shareOutGood)
print(LnShareOutGood)
cars['ratioLnMarketOut'] = (cars['LnMarkethare']/LnShareOutGood)
# Out:
# -0.15243654318923178

# %%
secondStage = smf.ols(formula='ratioLnMarketOut ~ minivans + passenger_cars + logPriceHat + hybrid + log_footprint + disp' ,data=cars).fit(cov_type='HC1')

print(secondStage.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       ratioLnMarketOut   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.111
# Method:                 Least Squares   F-statistic:                     3.428
# Date:                Sun, 24 Apr 2022   Prob (F-statistic):            0.00300
# Time:                        17:12:56   Log-Likelihood:                -748.15
# No. Observations:                 217   AIC:                             1510.
# Df Residuals:                     210   BIC:                             1534.
# Df Model:                           6
# Covariance Type:                  HC1
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         36.0343     37.865      0.952      0.341     -38.180     110.249
# minivans           3.9340      2.231      1.763      0.078      -0.438       8.306
# passenger_cars     0.1496      1.331      0.112      0.911      -2.459       2.758
# logPriceHat        7.2887      3.449      2.113      0.035       0.528      14.049
# hybrid             6.0612      5.469      1.108      0.268      -4.658      16.780
# log_footprint    -22.9697      7.131     -3.221      0.001     -36.947      -8.992
# disp               0.4851      1.329      0.365      0.715      -2.120       3.090
# ==============================================================================
# Omnibus:                        9.160   Durbin-Watson:                   1.747
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):                9.156
# Skew:                           0.491   Prob(JB):                       0.0103
# Kurtosis:                       3.222   Cond. No.                         577.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)

# %% [markdown]
# 3. Analyze your results. What is the interpretation of the coefficients on the features, the dummy variables and the price.

# %% [markdown]
# - The coefficient on minivans is 3.9340. minivans is a dummy variable. So a vehicle being a minivan leads to a 3.9340 in the variable ratioLnMarketOut, which translates into a 3.9340 * (log of the market share of the outside good) = 3.9340 * -0.1524 = -0.5995 change in log of market share of a car model. So an e^-0.5995 = 0.5491 change in the market share of a car model. minivans has a P value of 0.078, so it is significant at the 90% level.
#
# - The coefficient on passenger_cars is 0.1496. passenger_cars is a dummy variable. So a vehicle being a passenger_car leads to a  0.1496 in the variable ratioLnMarketOut, which translates into a 0.1496 * (log of the market share of the outside good) =  0.1496 * -0.1524 = -0.022799 change in log of market share of a car model. So an e^-0.022799 = 0.97746 change in the market share of a car model.
#
# - The coefficient on logPriceHat is 7.2887. So a one percent increase in PriceHat leads to a 7.2887 increase in ratioLnMarketOut, which translates into a 7.2887 * (log of the market share of the outside good) =  7.2887 * -0.1524 = -1.110798 change in log of market share of a car model. So an e^-1.110798 = 0.3293 change in the market share of a car model. logPriceHat has a P value of 0.035, so it is significant at the 95% level
#
# - The coefficient on log_footprint is -22.9697. So a one percent increase in footprint leads to a -22.9697 increase in  ratioLnMarketOut, which translates into a -22.9697 * (log of the market share of the outside good) = -22.9697 * -0.1524 = 3.5006 change in log of market share of a car model. So an e^3.5006 = 33.1347 change in the market share of a car model. logPriceHat has a P value of 0.001, so it is significant at the 99% level
#
# - The coefficient on hybrid is 6.0612. So a one unit increase in hybrid leads to a 6.0612 increase in  ratioLnMarketOut, which translates into a 6.0612 * (log of the market share of the outside good) = 6.0612 * -0.1524 = -0.9237 change in log of market share of a car model. So an e^-0.9237 = 0.3970 change in the market share of a car model.
#
# - The coefficient on disp is 0.4851. So a one unit increase in disp leads to a 0.4851 increase in  ratioLnMarketOut, which translates into a 0.4851 * (log of the market share of the outside good) = 0.4851 * -0.1524 = -0.07393 change in log of market share of a car model. So an e^-0.07393 = 0.9287 change in the market share of a car model.
